# %%
import pandas as pd
pd.__version__
# Out:
# '1.1.3'

# %%
pd.DataFrame({"A":[1,2,3,4,5],"B":[5,4,3,2,1]})
# Out:
#    A  B
# 0  1  5
# 1  2  4
# 2  3  3
# 3  4  2
# 4  5  1

# %%
lst = [["A",1],["B",2],["C",3]]
k = pd.DataFrame(lst)
k.columns = ["Y","Z"]
k
# Out:
#    Y  Z
# 0  A  1
# 1  B  2
# 2  C  3

# %%
k = pd.DataFrame(lst,columns = ["Y","Z"],index = [101,102,103])
k
# Out:
#      Y  Z
# 101  A  1
# 102  B  2
# 103  C  3

# %%
df  = pd.read_csv("pandasDS1")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 36634 entries, 0 to 36633
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   policyID            36634 non-null  int64
#  1   statecode           36634 non-null  object
#  2   county              36634 non-null  object
#  3   eq_site_limit       36634 non-null  float64
#  4   hu_site_limit       36634 non-null  float64
#  5   fl_site_limit       36634 non-null  float64
#  6   fr_site_limit       36634 non-null  float64
#  7   tiv_2011            36634 non-null  float64
#  8   tiv_2012            36634 non-null  float64
#  9   eq_site_deductible  36634 non-null  float64
#  10  hu_site_deductible  36634 non-null  float64
#  11  fl_site_deductible  36634 non-null  float64
#  12  fr_site_deductible  36634 non-null  int64
#  13  point_latitude      36634 non-null  float64
#  14  point_longitude     36634 non-null  float64
# ...

# %%
df.head()
# Out:
#    policyID statecode       county  eq_site_limit  hu_site_limit  \
# 0    119736        FL  CLAY COUNTY       498960.0      498960.00
# 1    448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2    206893        FL  CLAY COUNTY       190724.4      190724.40
# 3    333743        FL  CLAY COUNTY            0.0       79520.76
# 4    172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
df.shape
# Out:
# (36634, 18)

# %%
df.isna().sum()
# Out:
# policyID              0
# statecode             0
# county                0
# eq_site_limit         0
# hu_site_limit         0
# fl_site_limit         0
# fr_site_limit         0
# tiv_2011              0
# tiv_2012              0
# eq_site_deductible    0
# hu_site_deductible    0
# fl_site_deductible    0
# fr_site_deductible    0
# point_latitude        0
# point_longitude       0
# line                  0
# construction          0
# point_granularity     0
# dtype: int64

# %%
df.county
# Out:
# 0            CLAY COUNTY
# 1            CLAY COUNTY
# 2            CLAY COUNTY
# 3            CLAY COUNTY
# 4            CLAY COUNTY
#               ...
# 36629    PINELLAS COUNTY
# 36630    PINELLAS COUNTY
# 36631    PINELLAS COUNTY
# 36632    PINELLAS COUNTY
# 36633    PINELLAS COUNTY
# Name: county, Length: 36634, dtype: object

# %%
df["county"]
# Out:
# 0            CLAY COUNTY
# 1            CLAY COUNTY
# 2            CLAY COUNTY
# 3            CLAY COUNTY
# 4            CLAY COUNTY
#               ...
# 36629    PINELLAS COUNTY
# 36630    PINELLAS COUNTY
# 36631    PINELLAS COUNTY
# 36632    PINELLAS COUNTY
# 36633    PINELLAS COUNTY
# Name: county, Length: 36634, dtype: object

# %%
df.describe(include="all")
# Out:
#              policyID statecode             county  eq_site_limit  \
# count    36634.000000     36634              36634   3.663400e+04
# unique            NaN         1                 67            NaN
# top               NaN        FL  MIAMI DADE COUNTY            NaN
# freq              NaN     36634               4315            NaN
# mean    548661.937189       NaN                NaN   7.314780e+05
# std     259912.926494       NaN                NaN   1.752300e+07
# min     100074.000000       NaN                NaN   0.000000e+00
# 25%     323647.750000       NaN                NaN   0.000000e+00
# 50%     548525.000000       NaN                NaN   0.000000e+00
# 75%     774252.000000       NaN                NaN   0.000000e+00
# max     999971.000000       NaN                NaN   2.160000e+09
#
#         hu_site_limit  fl_site_limit  fr_site_limit      tiv_2011  \
# count    3.663400e+04   3.663400e+04   3.663400e+04  3.663400e+04
# ...

# %%
df.describe()
# Out:
#             policyID  eq_site_limit  hu_site_limit  fl_site_limit  \
# count   36634.000000   3.663400e+04   3.663400e+04   3.663400e+04
# mean   548661.937189   7.314780e+05   2.074348e+06   6.646009e+05
# std    259912.926494   1.752300e+07   1.964150e+07   1.746114e+07
# min    100074.000000   0.000000e+00   0.000000e+00   0.000000e+00
# 25%    323647.750000   0.000000e+00   4.248106e+04   0.000000e+00
# 50%    548525.000000   0.000000e+00   1.926911e+05   0.000000e+00
# 75%    774252.000000   0.000000e+00   9.163381e+05   0.000000e+00
# max    999971.000000   2.160000e+09   2.160000e+09   2.160000e+09
#
#        fr_site_limit      tiv_2011      tiv_2012  eq_site_deductible  \
# count   3.663400e+04  3.663400e+04  3.663400e+04        3.663400e+04
# mean    9.911724e+05  2.172875e+06  2.571004e+06        7.787908e+02
# std     1.767178e+07  2.015015e+07  2.036777e+07        4.787979e+04
# min     0.000000e+00  9.000000e+01  7.337000e+01        0.000000e+00
# ...

# %%
col = list(df.columns)
col
# Out:
# ['policyID',
#  'statecode',
#  'county',
#  'eq_site_limit',
#  'hu_site_limit',
#  'fl_site_limit',
#  'fr_site_limit',
#  'tiv_2011',
#  'tiv_2012',
#  'eq_site_deductible',
#  'hu_site_deductible',
#  'fl_site_deductible',
#  'fr_site_deductible',
#  'point_latitude',
#  'point_longitude',
#  'line',
#  'construction',
#  'point_granularity']

# %%
df.rename(columns = {"policyID":"ID_Policy"},inplace =True)

# %%
df.head()
# Out:
#    ID_Policy statecode       county  eq_site_limit  hu_site_limit  \
# 0     119736        FL  CLAY COUNTY       498960.0      498960.00
# 1     448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 2     206893        FL  CLAY COUNTY       190724.4      190724.40
# 3     333743        FL  CLAY COUNTY            0.0       79520.76
# 4     172534        FL  CLAY COUNTY            0.0      254281.50
#
#    fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  eq_site_deductible  \
# 0       498960.0       498960.0   498960.00   792148.90                 0.0
# 1      1322376.3      1322376.3  1322376.30  1438163.57                 0.0
# 2       190724.4       190724.4   190724.40   192476.78                 0.0
# 3            0.0            0.0    79520.76    86854.48                 0.0
# 4            0.0       254281.5   254281.50   246144.49                 0.0
#
#    hu_site_deductible  fl_site_deductible  fr_site_deductible  point_latitude  \
# ...

# %%
import numpy as np
df.index = np.arange(36634,0,-1)

# %%
df
# Out:
#        ID_Policy statecode           county  eq_site_limit  hu_site_limit  \
# 36634     119736        FL      CLAY COUNTY       498960.0      498960.00
# 36633     448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 36632     206893        FL      CLAY COUNTY       190724.4      190724.40
# 36631     333743        FL      CLAY COUNTY            0.0       79520.76
# 36630     172534        FL      CLAY COUNTY            0.0      254281.50
# ...          ...       ...              ...            ...            ...
# 5         404309        FL  PINELLAS COUNTY            0.0       88722.00
# 4         465875        FL  PINELLAS COUNTY      1297057.5     1297057.50
# 3         791209        FL  PINELLAS COUNTY       173286.9      173286.90
# 2         322627        FL  PINELLAS COUNTY      1499781.6     1499781.60
# 1         398149        FL  PINELLAS COUNTY       373488.3      373488.30
#
#        fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  \
# ...

# %%
df.index= df["ID_Policy"]

# %%
df
# Out:
#            ID_Policy statecode           county  eq_site_limit  hu_site_limit  \
# ID_Policy
# 119736        119736        FL      CLAY COUNTY       498960.0      498960.00
# 448094        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 206893        206893        FL      CLAY COUNTY       190724.4      190724.40
# 333743        333743        FL      CLAY COUNTY            0.0       79520.76
# 172534        172534        FL      CLAY COUNTY            0.0      254281.50
# ...              ...       ...              ...            ...            ...
# 404309        404309        FL  PINELLAS COUNTY            0.0       88722.00
# 465875        465875        FL  PINELLAS COUNTY      1297057.5     1297057.50
# 791209        791209        FL  PINELLAS COUNTY       173286.9      173286.90
# 322627        322627        FL  PINELLAS COUNTY      1499781.6     1499781.60
# 398149        398149        FL  PINELLAS COUNTY       373488.3      373488.30
#
# ...

# %%
subset = df[["ID_Policy","statecode"]]
subset.index = np.arange(1,36635)
subset.head().to_csv("Subset.csv")
subset.head()
# Out:
#    ID_Policy statecode
# 1     119736        FL
# 2     448094        FL
# 3     206893        FL
# 4     333743        FL
# 5     172534        FL

# %%
subset.iloc[10:15,]
# Out:
#     ID_Policy statecode
# 11     253816        FL
# 12     894922        FL
# 13     422834        FL
# 14     582721        FL
# 15     842700        FL

# %%
df.iloc[10:15,2:6] 
#index locator
# Out:
#                 county  eq_site_limit  hu_site_limit  fl_site_limit
# ID_Policy
# 253816     CLAY COUNTY       831498.3      831498.30       831498.3
# 894922     CLAY COUNTY            0.0       24059.09            0.0
# 422834     CLAY COUNTY            0.0       48115.94            0.0
# 582721     CLAY COUNTY            0.0       28869.12            0.0
# 842700     CLAY COUNTY            0.0       56135.64            0.0

# %%
#filter
subset[subset.ID_Policy > 999900]
# Out:
#        ID_Policy statecode
# 1675      999971        FL
# 6887      999934        FL
# 8171      999959        FL
# 35573     999908        FL
# 36262     999970        FL

# %%
df[df.ID_Policy > 999900]
# Out:
#            ID_Policy statecode           county  eq_site_limit  hu_site_limit  \
# ID_Policy
# 999971        999971        FL   VOLUSIA COUNTY            0.0      208962.00
# 999934        999934        FL  ESCAMBIA COUNTY            0.0      120360.03
# 999959        999959        FL  ESCAMBIA COUNTY            0.0       66150.00
# 999908        999908        FL    MARION COUNTY        72084.6       72084.60
# 999970        999970        FL     PASCO COUNTY            0.0      530317.42
#
#            fl_site_limit  fr_site_limit   tiv_2011   tiv_2012  \
# ID_Policy
# 999971               0.0       208962.0  208962.00  232532.91
# 999934               0.0            0.0  120360.03  154963.54
# 999959               0.0        66150.0   66150.00   87957.27
# 999908           72084.6        72084.6   72084.60   73563.06
# 999970               0.0            0.0  530317.42  669759.08
#
#            eq_site_deductible  hu_site_deductible  fl_site_deductible  \
# ID_Policy
# ...

# %%
df[df.construction == "Masonry"]
# Out:
#            ID_Policy statecode           county  eq_site_limit  hu_site_limit  \
# ID_Policy
# 119736        119736        FL      CLAY COUNTY       498960.0      498960.00
# 448094        448094        FL      CLAY COUNTY      1322376.3     1322376.30
# 785275        785275        FL      CLAY COUNTY            0.0      515035.62
# 142071        142071        FL      CLAY COUNTY       705600.0      705600.00
# 253816        253816        FL      CLAY COUNTY       831498.3      831498.30
# ...              ...       ...              ...            ...            ...
# 645213        645213        FL  PINELLAS COUNTY            0.0     1728847.80
# 546178        546178        FL  PINELLAS COUNTY            0.0     1331880.30
# 465875        465875        FL  PINELLAS COUNTY      1297057.5     1297057.50
# 322627        322627        FL  PINELLAS COUNTY      1499781.6     1499781.60
# 398149        398149        FL  PINELLAS COUNTY       373488.3      373488.30
#
# ...

# %%
# and -> & or -> |
df[(df.construction == "Masonry") & (df.ID_Policy > 999900)].iloc[:,0:5]
# Out:
#            ID_Policy statecode        county  eq_site_limit  hu_site_limit
# ID_Policy
# 999970        999970        FL  PASCO COUNTY            0.0      530317.42

# %%
# LOC locator
df.loc[df.ID_Policy > 999900 , ["ID_Policy","statecode"]]
# Out:
#            ID_Policy statecode
# ID_Policy
# 999971        999971        FL
# 999934        999934        FL
# 999959        999959        FL
# 999908        999908        FL
# 999970        999970        FL

# %%
df[df.ID_Policy > 999900][["ID_Policy","statecode"]]
# Out:
#            ID_Policy statecode
# ID_Policy
# 999971        999971        FL
# 999934        999934        FL
# 999959        999959        FL
# 999908        999908        FL
# 999970        999970        FL

# %%
df[["tiv_2011","tiv_2012"]].head()
# Out:
#              tiv_2011    tiv_2012
# ID_Policy
# 119736      498960.00   792148.90
# 448094     1322376.30  1438163.57
# 206893      190724.40   192476.78
# 333743       79520.76    86854.48
# 172534      254281.50   246144.49

# %%
df["tiv_total"] = df.tiv_2011 + df.tiv_2012
df["reduced"] = ((df.tiv_2011 - df.tiv_2012)**2)**0.5
df.head()
# Out:
#            ID_Policy statecode       county  eq_site_limit  hu_site_limit  \
# ID_Policy
# 119736        119736        FL  CLAY COUNTY       498960.0      498960.00
# 448094        448094        FL  CLAY COUNTY      1322376.3     1322376.30
# 206893        206893        FL  CLAY COUNTY       190724.4      190724.40
# 333743        333743        FL  CLAY COUNTY            0.0       79520.76
# 172534        172534        FL  CLAY COUNTY            0.0      254281.50
#
#            fl_site_limit  fr_site_limit    tiv_2011    tiv_2012  \
# ID_Policy
# 119736          498960.0       498960.0   498960.00   792148.90
# 448094         1322376.3      1322376.3  1322376.30  1438163.57
# 206893          190724.4       190724.4   190724.40   192476.78
# 333743               0.0            0.0    79520.76    86854.48
# 172534               0.0       254281.5   254281.50   246144.49
#
#            eq_site_deductible  hu_site_deductible  fl_site_deductible  \
# ID_Policy
# ...

# %%
#unique
df["construction"].unique(),len(df["construction"].unique())
# Out:
# (array(['Masonry', 'Wood', 'Reinforced Concrete', 'Reinforced Masonry',
#         'Steel Frame'], dtype=object),
#  5)

# %%
#Value counts
df.index = np.arange(1,36635)

df["construction"].value_counts()

#df["eq_site_limit"].value_counts()
# Out:
# Wood                   21581
# Masonry                 9257
# Reinforced Masonry      4225
# Reinforced Concrete     1299
# Steel Frame              272
# Name: construction, dtype: int64

# %%
#Total, mean median
df.eq_site_limit.mean()
# Out:
# 731478.0068461001

# %%
df["eq_site_limit"].std()
# Out:
# 17523003.588415045

# %%
df[["tiv_2011","tiv_2012"]].mean()
# Out:
# tiv_2011    2.172875e+06
# tiv_2012    2.571004e+06
# dtype: float64

# %%
#froupby
df.groupby(by="construction")[["eq_site_limit","hu_site_limit","fl_site_limit","fr_site_limit","tiv_2011","tiv_2012"]].std()
# Out:
#                      eq_site_limit  hu_site_limit  fl_site_limit  \
# construction
# Masonry               3.930914e+05   4.015061e+05   3.612617e+05
# Reinforced Concrete   7.998935e+06   7.198729e+06   7.313510e+06
# Reinforced Masonry    1.663713e+06   1.920391e+06   1.603358e+06
# Steel Frame           1.937804e+08   1.975370e+08   1.939860e+08
# Wood                  6.506716e+04   9.355684e+04   5.451127e+04
#
#                      fr_site_limit      tiv_2011      tiv_2012
# construction
# Masonry               4.588334e+05  3.909296e+05  5.336659e+05
# Reinforced Concrete   9.024839e+06  6.458193e+06  9.062552e+06
# Reinforced Masonry    2.282589e+06  1.863190e+06  2.510370e+06
# Steel Frame           1.930024e+08  1.998633e+08  1.904033e+08
# Wood                  6.831538e+04  9.353186e+04  1.188935e+05

# %%
#Pivot
df.pivot_table(columns=["construction"],values=["eq_site_limit","hu_site_limit","fl_site_limit","fr_site_limit","tiv_2011","tiv_2012"],aggfunc= "std")
# Out:
# construction         Masonry  Reinforced Concrete  Reinforced Masonry  \
# eq_site_limit  393091.441445         7.998935e+06        1.663713e+06
# fl_site_limit  361261.746671         7.313510e+06        1.603358e+06
# fr_site_limit  458833.443953         9.024839e+06        2.282589e+06
# hu_site_limit  401506.058659         7.198729e+06        1.920391e+06
# tiv_2011       390929.629466         6.458193e+06        1.863190e+06
# tiv_2012       533665.944339         9.062552e+06        2.510370e+06
#
# construction    Steel Frame           Wood
# eq_site_limit  1.937804e+08   65067.158818
# fl_site_limit  1.939860e+08   54511.273092
# fr_site_limit  1.930024e+08   68315.383946
# hu_site_limit  1.975370e+08   93556.841824
# tiv_2011       1.998633e+08   93531.863535
# tiv_2012       1.904033e+08  118893.544428

# %%
#Sort
df.sort_values(by = "tiv_2012",ascending = False,inplace = True)
df.tail()
#df.construction.value_counts()
# Out:
#        ID_Policy statecode             county  eq_site_limit  hu_site_limit  \
# 8787      475342        FL  SANTA ROSA COUNTY           90.0           90.0
# 8249      347262        FL  SANTA ROSA COUNTY           90.0           90.0
# 8985      841424        FL  SANTA ROSA COUNTY           90.0           90.0
# 8229      830470        FL  SANTA ROSA COUNTY           90.0           90.0
# 30089     410613        FL   HIGHLANDS COUNTY            0.0           90.0
#
#        fl_site_limit  fr_site_limit  tiv_2011  tiv_2012  eq_site_deductible  \
# 8787            90.0           90.0      90.0     79.99                 0.0
# 8249            90.0           90.0      90.0     78.27                 0.0
# 8985            90.0           90.0      90.0     76.88                 0.0
# 8229            90.0           90.0      90.0     76.01                 0.0
# 30089            0.0           90.0      90.0     73.37                 0.0
#
# ...

# %%
df.sort_values(by = ["county","tiv_2012"],inplace = True)
df.head()
# Out:
#       ID_Policy statecode          county  eq_site_limit  hu_site_limit  \
# 9619     608101        FL  ALACHUA COUNTY          360.0          360.0
# 9623     940231        FL  ALACHUA COUNTY          360.0          360.0
# 9622     418558        FL  ALACHUA COUNTY          360.0          360.0
# 9817     475441        FL  ALACHUA COUNTY          360.0          360.0
# 9522     557196        FL  ALACHUA COUNTY          270.0          270.0
#
#       fl_site_limit  fr_site_limit  tiv_2011  tiv_2012  eq_site_deductible  \
# 9619          360.0          360.0     360.0    275.00                 0.0
# 9623          360.0          360.0     360.0    280.25                 0.0
# 9622          360.0          360.0     360.0    298.60                 0.0
# 9817          360.0          360.0     360.0    303.34                 0.0
# 9522          270.0          270.0     270.0    305.08                 0.0
#
#       hu_site_deductible  fl_site_deductible  fr_site_deductible  \
# ...

# %%
#Concatenate Dataframes
df1 = pd.DataFrame({"PCode":[101,102,103,104],"PDesc":['Laptop','Phone','Camera','Keyboard']})
df2 = pd.DataFrame({"PCode":[105,106,107,108],"PDesc":['Mouse','Speaker','Monitor','UPS']})
df1,df2
# Out:
# (   PCode     PDesc
#  0    101    Laptop
#  1    102     Phone
#  2    103    Camera
#  3    104  Keyboard,
#     PCode    PDesc
#  0    105    Mouse
#  1    106  Speaker
#  2    107  Monitor
#  3    108      UPS)

# %%
df3 = pd.concat([df1,df2])
df3.index = np.arange(0,8)
df3
# Out:
#    PCode     PDesc
# 0    101    Laptop
# 1    102     Phone
# 2    103    Camera
# 3    104  Keyboard
# 4    105     Mouse
# 5    106   Speaker
# 6    107   Monitor
# 7    108       UPS

# %%
df3 = pd.concat([df1,df2],ignore_index=True)
df3
# Out:
#    PCode     PDesc
# 0    101    Laptop
# 1    102     Phone
# 2    103    Camera
# 3    104  Keyboard
# 4    105     Mouse
# 5    106   Speaker
# 6    107   Monitor
# 7    108       UPS

# %%
#Merging Dataframes

# %%
k = {"ProductCode":[101,101,104,102,106,109],"Amt":[123,324,541,768,12,999]}
print(k)
df4 = pd.DataFrame(k)
df4
# Out:
# {'ProductCode': [101, 101, 104, 102, 106, 109], 'Amt': [123, 324, 541, 768, 12, 999]}
#    ProductCode  Amt
# 0          101  123
# 1          101  324
# 2          104  541
# 3          102  768
# 4          106   12
# 5          109  999

# %%
#I want desc for df4 from df3

# %%
df4.merge(right = df3,how = "left",left_on = "ProductCode",right_on="PCode")
# Out:
#    ProductCode  Amt  PCode     PDesc
# 0          101  123  101.0    Laptop
# 1          101  324  101.0    Laptop
# 2          104  541  104.0  Keyboard
# 3          102  768  102.0     Phone
# 4          106   12  106.0   Speaker
# 5          109  999    NaN       NaN

# %%
df4.merge(right = df3,how = "right",left_on = "ProductCode",right_on="PCode")
# Out:
#    ProductCode    Amt  PCode     PDesc
# 0        101.0  123.0    101    Laptop
# 1        101.0  324.0    101    Laptop
# 2        102.0  768.0    102     Phone
# 3          NaN    NaN    103    Camera
# 4        104.0  541.0    104  Keyboard
# 5          NaN    NaN    105     Mouse
# 6        106.0   12.0    106   Speaker
# 7          NaN    NaN    107   Monitor
# 8          NaN    NaN    108       UPS

# %%
df4.merge(right = df3,how = 'inner',left_on = "ProductCode",right_on="PCode")
# Out:
#    ProductCode  Amt  PCode     PDesc
# 0          101  123    101    Laptop
# 1          101  324    101    Laptop
# 2          104  541    104  Keyboard
# 3          102  768    102     Phone
# 4          106   12    106   Speaker

# %%
df4.merge(right = df3,how = 'outer',left_on = "ProductCode",right_on="PCode").sort_values(by = "PCode"`)
# Out:
#    ProductCode    Amt  PCode     PDesc
# 0        101.0  123.0  101.0    Laptop
# 1        101.0  324.0  101.0    Laptop
# 3        102.0  768.0  102.0     Phone
# 6          NaN    NaN  103.0    Camera
# 2        104.0  541.0  104.0  Keyboard
# 7          NaN    NaN  105.0     Mouse
# 4        106.0   12.0  106.0   Speaker
# 8          NaN    NaN  107.0   Monitor
# 9          NaN    NaN  108.0       UPS
# 5        109.0  999.0    NaN       NaN
